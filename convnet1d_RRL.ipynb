# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import sys
import time

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline 
import tensorflow as tf

from parser_RRL import CIFAR10

# %%
config = tf.ConfigProto()
#config.gpu_options.per_process_gpu_memory_fraction = 0.4
tf.set_random_seed(1)
sess = tf.InteractiveSession(config=config)

# %%
# Load dataset
batch_size = 64
cifar10 = CIFAR10(batch_size=batch_size, validation_proportion=0.1, augment_data=False, file='data_RRL.csv')

SUMMARIES_DIR = './summaries/convnet'

# %%
# Model blocks
def conv_layer(input_tensor, kernel_shape, layer_name):
    # input_tensor b01c
    # kernel_shape 01-in-out
    weights = tf.get_variable("weights", kernel_shape,
                               initializer = tf.contrib.layers.xavier_initializer_conv2d())
    biases = tf.get_variable("biases", [kernel_shape[3]],
                             initializer=tf.constant_initializer(0.05))
    
    tf.summary.histogram(layer_name + "/weights", weights)
    tf.summary.histogram(layer_name + "/biases", biases)
    
    # Other options are to use He et. al init. for weights and 0.01 
    # to init. biases.
    conv = tf.nn.conv2d(input_tensor, weights, 
                       strides = [1, 1, 1, 1], padding='SAME')
    return tf.nn.relu(conv + biases)

def fc_layer(input_tensor, weights_shape, layer_name):
    # weights_shape in-out
    weights = tf.get_variable("weights", weights_shape,
                              initializer = tf.contrib.layers.xavier_initializer())
    biases = tf.get_variable("biases", [weights_shape[1]],
                             initializer=tf.constant_initializer(0.0))
    tf.summary.histogram(layer_name + "/weights", weights)
    tf.summary.histogram(layer_name + "/biases", biases)
    mult_out = tf.matmul(input_tensor, weights)
    return tf.nn.relu(mult_out+biases)

# %%
# Model
model_input = tf.placeholder(tf.float32, name='model_input', 
                             shape=(batch_size,1,200,1))
tf.summary.image('input', model_input, 10)

keep_prob = tf.placeholder(tf.float32, name='dropout_prob', shape=())

target = tf.placeholder(tf.float32, name='target', shape=(batch_size, 4))

# First convolution layer
layer_name = 'conv1'
with tf.variable_scope(layer_name):
    conv1_out = conv_layer(model_input, [1, 3, 1, 20], layer_name)
# First pooling layer
with tf.name_scope('pool1'):
    pool1_out = tf.nn.avg_pool(conv1_out, ksize=[1, 2, 2, 1],
                strides=[1, 2, 2, 1], padding='SAME',
                name='pool1')
    

# Second convolution layer
layer_name = 'conv2'
with tf.variable_scope(layer_name):
    conv2_out = conv_layer(pool1_out, [1, 3, 20, 20], layer_name)
# Second pooling layer
with tf.name_scope('pool2'):
    pool2_out = tf.nn.avg_pool(conv2_out, ksize=[1, 2, 2, 1],
                            strides=[1, 2, 2, 1], padding='SAME',
                            name='pool2')

# %%
_,_,dim3,dim4 = pool2_out.shape

# %%
pool2_out_flat = tf.reshape(pool2_out, [-1, 1*dim3.value*dim4.value], name='pool2_flat')
# First fully connected layer
layer_name = 'fc1'
with tf.variable_scope(layer_name):
    fc1_out = fc_layer(pool2_out_flat, [1*dim3.value*dim4.value, 500], layer_name)
fc1_out_drop = tf.nn.dropout(fc1_out, keep_prob)

# Second fully connected layer
layer_name = 'fc2'
with tf.variable_scope(layer_name):
    fc2_out = fc_layer(fc1_out_drop, [500, 250], layer_name)
fc2_out_drop = tf.nn.dropout(fc2_out, keep_prob)


# Third fully connected layer
layer_name = 'fc3'
with tf.variable_scope(layer_name):
    fc3_out = fc_layer(fc2_out_drop, [250,4], layer_name)
model_output = fc3_out


with tf.name_scope('loss_function'):
    cross_entropy = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits=model_output, labels=target,
                                           name='cross_entropy'))
    tf.summary.scalar('cross_entropy', cross_entropy)

# %%
# Optimization
with tf.name_scope('optimizer'):
    optimizer = tf.train.AdamOptimizer()
    grads_vars = optimizer.compute_gradients(cross_entropy)
    optimizer.apply_gradients(grads_vars)
    train_step = optimizer.minimize(cross_entropy)

# Metrics
correct_prediction = tf.equal(tf.argmax(model_output, 1),
                             tf.argmax(target, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name='accuracy')
tf.summary.scalar('accuracy', accuracy)

# Useful training functions
def validate():
    batches = cifar10.getValidationSet(asBatches=True)
    accs = []
    for batch in batches:
        data, labels = batch
        acc = sess.run(accuracy,
                       feed_dict={
                model_input: data,
                target: labels,
                keep_prob: 1.0
            })
        accs.append(acc)
    mean_acc = np.array(accs).mean()
    summary = sess.run(merged,
                       feed_dict={
                model_input: data,
                target: labels,
                keep_prob: 1.0
            })
    return summary, mean_acc
def test():
    batches = cifar10.getTestSet(asBatches=True)
    accs = []
    for batch in batches:
        data, labels = batch
        acc = sess.run(accuracy,
                       feed_dict={
                model_input: data,
                target: labels,
                keep_prob: 1.0
            })
        accs.append(acc)
    mean_acc = np.array(accs).mean()
    return mean_acc

# %%
# Train model
merged = tf.summary.merge_all()
train_writer = tf.summary.FileWriter(SUMMARIES_DIR+'/train',
                                     sess.graph)
validation_writer = tf.summary.FileWriter(SUMMARIES_DIR+'/validation')
sess.run(tf.global_variables_initializer())
cifar10.reset()
print("Trainable variables")
for n in tf.trainable_variables():
    print(n.name)

epochs = 200
mean_gradients = np.zeros([len(tf.trainable_variables()), epochs])
std_gradients = np.zeros([len(tf.trainable_variables()), epochs])

t_i = time.time()
n_batches = cifar10.n_batches
while cifar10.getEpoch() < epochs:
    epoch = cifar10.getEpoch()
    batch, batch_idx = cifar10.nextBatch()
    batch_data = batch[0]
    batch_labels = batch[1]
    
    # just a training iteration
    _ = sess.run(train_step,
                feed_dict={
            model_input: batch_data,
            target: batch_labels,
            keep_prob: 0.5
        })
    
    step = batch_idx+epoch*n_batches
    
    # Write training summary
    if step%50==0:
        summary = sess.run(merged,
                          feed_dict={
                model_input: batch_data,
                target: batch_labels,
                keep_prob: 0.5 # set to 1.0 at inference time
            })
        train_writer.add_summary(summary, step)
        
    # gradient (by layer) statistics over last training batch & validation summary
    if batch_idx==0:
        loss, acc, grads = sess.run((cross_entropy, accuracy, grads_vars), 
                      feed_dict={
            model_input: batch_data,
            target: batch_labels,
            keep_prob: 1.0
        })

        for layer in range(len(tf.trainable_variables())):
            mean_gradients[layer, epoch] = np.mean(np.abs(grads[layer][0]))
            std_gradients[layer, epoch] = np.std(np.abs(grads[layer][0]))
        print("Epoch %d, training loss %f, accuracy %f" % (epoch, loss, acc))
        
        summary, validation_accuracy = validate()
        validation_writer.add_summary(summary, step)
        print("Validation accuracy %f" % validation_accuracy)
        print("Time elapsed", (time.time()-t_i)/60.0, "minutes")
train_writer.flush()
validation_writer.flush()
test_acc = test()
print("Testing set accuracy %f" % test_acc)
# Out:
# Trainable variables
# conv1/weights:0
# conv1/biases:0
# conv2/weights:0
# conv2/biases:0
# fc1/weights:0
# fc1/biases:0
# fc2/weights:0
# fc2/biases:0
# fc3/weights:0
# fc3/biases:0
# Epoch 0, training loss 1.260949, accuracy 0.515625
# Validation accuracy 0.482955
# Time elapsed 0.0034262498219807943 minutes
# Epoch 1, training loss 0.996535, accuracy 0.531250
# Validation accuracy 0.482955
# Time elapsed 0.03437213102976481 minutes
# Epoch 2, training loss 1.075484, accuracy 0.453125
# Validation accuracy 0.482955
# Time elapsed 0.062433373928070066 minutes
# Epoch 3, training loss 1.082072, accuracy 0.375000
# Validation accuracy 0.477273
# Time elapsed 0.10653899908065796 minutes
# Epoch 4, training loss 0.924560, accuracy 0.546875
# Validation accuracy 0.495739
# Time elapsed 0.13954649368921915 minutes
# Epoch 5, training loss 0.902525, accuracy 0.609375
# Validation accuracy 0.568182
# Time elapsed 0.16613227128982544 minutes
# Epoch 6, training loss 0.757684, accuracy 0.625000
# Validation accuracy 0.589489
# Time elapsed 0.1880962371826172 minutes
# Epoch 7, training loss 0.745688, accuracy 0.687500
# Validation accuracy 0.599432
# Time elapsed 0.22922799189885457 minutes
# Epoch 8, training loss 0.716310, accuracy 0.640625
# Validation accuracy 0.615057
# Time elapsed 0.2571238438288371 minutes
# Epoch 9, training loss 0.842939, accuracy 0.531250
# Validation accuracy 0.610795
# Time elapsed 0.2829300880432129 minutes
# Epoch 10, training loss 0.818030, accuracy 0.609375
# Validation accuracy 0.622159
# Time elapsed 0.31700430711110433 minutes
# Epoch 11, training loss 0.817119, accuracy 0.546875
# Validation accuracy 0.607955
# Time elapsed 0.3422324617703756 minutes
# Epoch 12, training loss 0.814331, accuracy 0.593750
# Validation accuracy 0.613636
# Time elapsed 0.36785566806793213 minutes
# Epoch 13, training loss 0.718739, accuracy 0.656250
# Validation accuracy 0.630682
# Time elapsed 0.39241002798080443 minutes
# Epoch 14, training loss 0.906721, accuracy 0.546875
# Validation accuracy 0.630682
# Time elapsed 0.42273581425348916 minutes
# Epoch 15, training loss 0.793222, accuracy 0.578125
# Validation accuracy 0.629261
# Time elapsed 0.4451283534367879 minutes
# Epoch 16, training loss 0.740712, accuracy 0.625000
# Validation accuracy 0.630682
# Time elapsed 0.46960139671961465 minutes
# Epoch 17, training loss 0.597854, accuracy 0.750000
# Validation accuracy 0.633523
# Time elapsed 0.4945040225982666 minutes
# Epoch 18, training loss 0.611389, accuracy 0.750000
# Validation accuracy 0.627841
# Time elapsed 0.5238237420717875 minutes
# Epoch 19, training loss 0.695992, accuracy 0.703125
# Validation accuracy 0.630682
# Time elapsed 0.5564070502916972 minutes
# Epoch 20, training loss 0.661438, accuracy 0.656250
# Validation accuracy 0.643466
# Time elapsed 0.588977054754893 minutes
# Epoch 21, training loss 0.799427, accuracy 0.640625
# Validation accuracy 0.644886
# Time elapsed 0.6213087201118469 minutes
# Epoch 22, training loss 0.623625, accuracy 0.718750
# Validation accuracy 0.651989
# Time elapsed 0.6667169173558553 minutes
# Epoch 23, training loss 0.770702, accuracy 0.625000
# Validation accuracy 0.657670
# Time elapsed 0.6955203533172607 minutes
# Epoch 24, training loss 0.792145, accuracy 0.640625
# Validation accuracy 0.647727
# Time elapsed 0.7208163380622864 minutes
# Epoch 25, training loss 0.677768, accuracy 0.734375
# Validation accuracy 0.661932
# Time elapsed 0.7448281447092692 minutes
# Epoch 26, training loss 0.604214, accuracy 0.765625
# Validation accuracy 0.656250
# Time elapsed 0.7677087028821309 minutes
# Epoch 27, training loss 0.620027, accuracy 0.718750
# Validation accuracy 0.678977
# Time elapsed 0.7909372607866924 minutes
# Epoch 28, training loss 0.649477, accuracy 0.656250
# Validation accuracy 0.670455
# Time elapsed 0.8133034626642863 minutes
# Epoch 29, training loss 0.563089, accuracy 0.828125
# Validation accuracy 0.666193
# Time elapsed 0.8366126577059428 minutes
# Epoch 30, training loss 0.511041, accuracy 0.796875
# Validation accuracy 0.669034
# Time elapsed 0.8614934285481771 minutes
# Epoch 31, training loss 0.754674, accuracy 0.640625
# Validation accuracy 0.663352
# Time elapsed 0.8866829752922059 minutes
# Epoch 32, training loss 0.513693, accuracy 0.703125
# Validation accuracy 0.681818
# Time elapsed 0.9211681842803955 minutes
# Epoch 33, training loss 0.649374, accuracy 0.687500
# Validation accuracy 0.664773
# Time elapsed 0.9590694467226665 minutes
# Epoch 34, training loss 0.713564, accuracy 0.687500
# Validation accuracy 0.677557
# Time elapsed 1.0076390306154888 minutes
# Epoch 35, training loss 0.653075, accuracy 0.687500
# Validation accuracy 0.671875
# Time elapsed 1.0359623471895854 minutes
# Epoch 36, training loss 0.698797, accuracy 0.718750
# Validation accuracy 0.683239
# Time elapsed 1.062253212928772 minutes
# Epoch 37, training loss 0.683110, accuracy 0.703125
# Validation accuracy 0.676136
# Time elapsed 1.0877947131792705 minutes
# Epoch 38, training loss 0.671779, accuracy 0.625000
# Validation accuracy 0.674716
# Time elapsed 1.1138838291168214 minutes
# Epoch 39, training loss 0.551084, accuracy 0.734375
# Validation accuracy 0.673295
# Time elapsed 1.1416184226671855 minutes
# Epoch 40, training loss 0.623514, accuracy 0.687500
# Validation accuracy 0.693182
# Time elapsed 1.1722569743792215 minutes
# Epoch 41, training loss 0.673570, accuracy 0.671875
# Validation accuracy 0.686080
# Time elapsed 1.1975300033887228 minutes
# Epoch 42, training loss 0.474430, accuracy 0.843750
# Validation accuracy 0.683239
# Time elapsed 1.2230268557866415 minutes
# Epoch 43, training loss 0.513695, accuracy 0.734375
# Validation accuracy 0.686080
# Time elapsed 1.2477111021677654 minutes
# Epoch 44, training loss 0.504540, accuracy 0.750000
# Validation accuracy 0.667614
# Time elapsed 1.2699284036954244 minutes
# Epoch 45, training loss 0.535352, accuracy 0.687500
# Validation accuracy 0.687500
# Time elapsed 1.2915146271387736 minutes
# Epoch 46, training loss 0.604587, accuracy 0.734375
# Validation accuracy 0.686080
# Time elapsed 1.314156436920166 minutes
# Epoch 47, training loss 0.656052, accuracy 0.734375
# Validation accuracy 0.700284
# Time elapsed 1.3386471033096314 minutes
# Epoch 48, training loss 0.617702, accuracy 0.687500
# Validation accuracy 0.687500
# Time elapsed 1.3631986697514853 minutes
# Epoch 49, training loss 0.543905, accuracy 0.734375
# Validation accuracy 0.691761
# Time elapsed 1.3973097284634908 minutes
# Epoch 50, training loss 0.561666, accuracy 0.734375
# Validation accuracy 0.700284
# Time elapsed 1.430823067824046 minutes
# Epoch 51, training loss 0.619828, accuracy 0.656250
# Validation accuracy 0.694602
# Time elapsed 1.4589072465896606 minutes
# Epoch 52, training loss 0.553613, accuracy 0.765625
# Validation accuracy 0.705966
# Time elapsed 1.489030651251475 minutes
# Epoch 53, training loss 0.600353, accuracy 0.640625
# Validation accuracy 0.691761
# Time elapsed 1.5247363090515136 minutes
# Epoch 54, training loss 0.465101, accuracy 0.781250
# Validation accuracy 0.694602
# Time elapsed 1.5529380758603415 minutes
# Epoch 55, training loss 0.490891, accuracy 0.765625
# Validation accuracy 0.688920
# Time elapsed 1.5863948305447897 minutes
# Epoch 56, training loss 0.604333, accuracy 0.750000
# Validation accuracy 0.700284
# Time elapsed 1.6214965224266051 minutes
# Epoch 57, training loss 0.609036, accuracy 0.734375
# Validation accuracy 0.703125
# Time elapsed 1.6517245848973592 minutes
# Epoch 58, training loss 0.446276, accuracy 0.828125
# Validation accuracy 0.700284
# Time elapsed 1.675126854578654 minutes
# Epoch 59, training loss 0.668968, accuracy 0.671875
# Validation accuracy 0.708807
# Time elapsed 1.7153281052907308 minutes
# Epoch 60, training loss 0.564216, accuracy 0.765625
# Validation accuracy 0.701705
# Time elapsed 1.7460671186447143 minutes
# Epoch 61, training loss 0.622498, accuracy 0.734375
# Validation accuracy 0.698864
# Time elapsed 1.7740615844726562 minutes
# Epoch 62, training loss 0.585806, accuracy 0.687500
# Validation accuracy 0.707386
# Time elapsed 1.7995521267255148 minutes
# Epoch 63, training loss 0.611800, accuracy 0.765625
# Validation accuracy 0.705966
# Time elapsed 1.8255117535591125 minutes
# Epoch 64, training loss 0.609734, accuracy 0.718750
# Validation accuracy 0.701705
# Time elapsed 1.8513788859049478 minutes
# Epoch 65, training loss 0.590218, accuracy 0.656250
# Validation accuracy 0.708807
# Time elapsed 1.8762995799382527 minutes
# Epoch 66, training loss 0.640070, accuracy 0.640625
# Validation accuracy 0.710227
# Time elapsed 1.9008368094762167 minutes
# Epoch 67, training loss 0.516659, accuracy 0.796875
# Validation accuracy 0.705966
# Time elapsed 1.9238723834355673 minutes
# Epoch 68, training loss 0.491849, accuracy 0.781250
# Validation accuracy 0.704545
# Time elapsed 1.9462135513623555 minutes
# Epoch 69, training loss 0.450131, accuracy 0.843750
# Validation accuracy 0.718750
# Time elapsed 1.9681509017944336 minutes
# Epoch 70, training loss 0.546563, accuracy 0.734375
# Validation accuracy 0.705966
# Time elapsed 1.9895443360010783 minutes
# Epoch 71, training loss 0.476563, accuracy 0.812500
# Validation accuracy 0.703125
# Time elapsed 2.010658299922943 minutes
# Epoch 72, training loss 0.634643, accuracy 0.734375
# Validation accuracy 0.708807
# Time elapsed 2.0334108233451844 minutes
# Epoch 73, training loss 0.495258, accuracy 0.765625
# Validation accuracy 0.705966
# Time elapsed 2.0667370915412904 minutes
# Epoch 74, training loss 0.521013, accuracy 0.765625
# Validation accuracy 0.714489
# Time elapsed 2.090902233123779 minutes
# Epoch 75, training loss 0.397427, accuracy 0.875000
# Validation accuracy 0.697443
# Time elapsed 2.121183721224467 minutes
# Epoch 76, training loss 0.505778, accuracy 0.781250
# Validation accuracy 0.715909
# Time elapsed 2.1529177904129027 minutes
# Epoch 77, training loss 0.579225, accuracy 0.671875
# Validation accuracy 0.713068
# Time elapsed 2.1801228125890098 minutes
# Epoch 78, training loss 0.492264, accuracy 0.796875
# Validation accuracy 0.708807
# Time elapsed 2.2048594117164613 minutes
# Epoch 79, training loss 0.469941, accuracy 0.796875
# Validation accuracy 0.718750
# Time elapsed 2.2297125180562336 minutes
# Epoch 80, training loss 0.514470, accuracy 0.750000
# Validation accuracy 0.703125
# Time elapsed 2.2541422843933105 minutes
# Epoch 81, training loss 0.500190, accuracy 0.734375
# Validation accuracy 0.727273
# Time elapsed 2.285001981258392 minutes
# Epoch 82, training loss 0.464896, accuracy 0.812500
# Validation accuracy 0.728693
# Time elapsed 2.3118860125541687 minutes
# Epoch 83, training loss 0.595273, accuracy 0.687500
# Validation accuracy 0.721591
# Time elapsed 2.337124749024709 minutes
# Epoch 84, training loss 0.489432, accuracy 0.765625
# Validation accuracy 0.708807
# Time elapsed 2.363764985402425 minutes
# Epoch 85, training loss 0.553894, accuracy 0.765625
# Validation accuracy 0.700284
# Time elapsed 2.3864207665125527 minutes
# Epoch 86, training loss 0.494123, accuracy 0.734375
# Validation accuracy 0.717330
# Time elapsed 2.4078778942426045 minutes
# Epoch 87, training loss 0.445522, accuracy 0.781250
# Validation accuracy 0.715909
# Time elapsed 2.430033608277639 minutes
# Epoch 88, training loss 0.505111, accuracy 0.781250
# Validation accuracy 0.713068
# Time elapsed 2.4554675380388895 minutes
# Epoch 89, training loss 0.610712, accuracy 0.687500
# Validation accuracy 0.732955
# Time elapsed 2.4798338254292807 minutes
# Epoch 90, training loss 0.455765, accuracy 0.843750
# Validation accuracy 0.717330
# Time elapsed 2.5035820523897807 minutes
# Epoch 91, training loss 0.535889, accuracy 0.781250
# Validation accuracy 0.704545
# Time elapsed 2.52584764957428 minutes
# Epoch 92, training loss 0.533004, accuracy 0.781250
# Validation accuracy 0.735795
# Time elapsed 2.5482569138209024 minutes
# Epoch 93, training loss 0.456996, accuracy 0.828125
# Validation accuracy 0.721591
# Time elapsed 2.5714488943417866 minutes
# Epoch 94, training loss 0.486082, accuracy 0.812500
# Validation accuracy 0.710227
# Time elapsed 2.5971122781435647 minutes
# Epoch 95, training loss 0.558278, accuracy 0.687500
# Validation accuracy 0.721591
# Time elapsed 2.622062544027964 minutes
# Epoch 96, training loss 0.574233, accuracy 0.703125
# Validation accuracy 0.731534
# Time elapsed 2.645356369018555 minutes
# Epoch 97, training loss 0.586555, accuracy 0.750000
# Validation accuracy 0.731534
# Time elapsed 2.6681376457214356 minutes
# Epoch 98, training loss 0.420105, accuracy 0.843750
# Validation accuracy 0.731534
# Time elapsed 2.6906388282775877 minutes
# Epoch 99, training loss 0.533726, accuracy 0.718750
# Validation accuracy 0.727273
# Time elapsed 2.715773677825928 minutes
# Epoch 100, training loss 0.428296, accuracy 0.812500
# Validation accuracy 0.731534
# Time elapsed 2.7401751279830933 minutes
# Epoch 101, training loss 0.422195, accuracy 0.812500
# Validation accuracy 0.732955
# Time elapsed 2.765042304992676 minutes
# Epoch 102, training loss 0.459699, accuracy 0.781250
# Validation accuracy 0.731534
# Time elapsed 2.7878697514533997 minutes
# Epoch 103, training loss 0.414719, accuracy 0.812500
# Validation accuracy 0.711648
# Time elapsed 2.8102182586987814 minutes
# Epoch 104, training loss 0.463873, accuracy 0.843750
# Validation accuracy 0.718750
# Time elapsed 2.833909296989441 minutes
# Epoch 105, training loss 0.476046, accuracy 0.781250
# Validation accuracy 0.740057
# Time elapsed 2.8597526073455812 minutes
# Epoch 106, training loss 0.424782, accuracy 0.781250
# Validation accuracy 0.730114
# Time elapsed 2.885261050860087 minutes
# Epoch 107, training loss 0.505590, accuracy 0.812500
# Validation accuracy 0.717330
# Time elapsed 2.9080983360608417 minutes
# Epoch 108, training loss 0.492422, accuracy 0.765625
# Validation accuracy 0.727273
# Time elapsed 2.930337691307068 minutes
# Epoch 109, training loss 0.463720, accuracy 0.734375
# Validation accuracy 0.737216
# Time elapsed 2.9524697701136273 minutes
# Epoch 110, training loss 0.581536, accuracy 0.703125
# Validation accuracy 0.734375
# Time elapsed 2.9771397789319356 minutes
# Epoch 111, training loss 0.450748, accuracy 0.828125
# Validation accuracy 0.721591
# Time elapsed 3.0026761611302693 minutes
# Epoch 112, training loss 0.434905, accuracy 0.750000
# Validation accuracy 0.751420
# Time elapsed 3.0283856550852457 minutes
# Epoch 113, training loss 0.456991, accuracy 0.781250
# Validation accuracy 0.744318
# Time elapsed 3.0513554294904073 minutes
# Epoch 114, training loss 0.415337, accuracy 0.828125
# Validation accuracy 0.744318
# Time elapsed 3.0735769192377727 minutes
# Epoch 115, training loss 0.519534, accuracy 0.781250
# Validation accuracy 0.745739
# Time elapsed 3.096482749780019 minutes
# Epoch 116, training loss 0.420816, accuracy 0.859375
# Validation accuracy 0.745739
# Time elapsed 3.1176892717679343 minutes
# Epoch 117, training loss 0.528465, accuracy 0.796875
# Validation accuracy 0.728693
# Time elapsed 3.139392677942912 minutes
# Epoch 118, training loss 0.485338, accuracy 0.796875
# Validation accuracy 0.750000
# Time elapsed 3.1602632204691568 minutes
# Epoch 119, training loss 0.474868, accuracy 0.812500
# Validation accuracy 0.759943
# Time elapsed 3.1819684068361918 minutes
# Epoch 120, training loss 0.443690, accuracy 0.812500
# Validation accuracy 0.741477
# Time elapsed 3.2046868920326235 minutes
# Epoch 121, training loss 0.441904, accuracy 0.812500
# Validation accuracy 0.750000
# Time elapsed 3.2262754877408346 minutes
# Epoch 122, training loss 0.437818, accuracy 0.812500
# Validation accuracy 0.742898
# Time elapsed 3.2583729147911074 minutes
# Epoch 123, training loss 0.446219, accuracy 0.796875
# Validation accuracy 0.747159
# Time elapsed 3.2891958872477214 minutes
# Epoch 124, training loss 0.434289, accuracy 0.781250
# Validation accuracy 0.738636
# Time elapsed 3.3156300663948057 minutes
# Epoch 125, training loss 0.353776, accuracy 0.843750
# Validation accuracy 0.745739
# Time elapsed 3.3411978761355083 minutes
# Epoch 126, training loss 0.450263, accuracy 0.812500
# Validation accuracy 0.755682
# Time elapsed 3.365372852484385 minutes
# Epoch 127, training loss 0.413916, accuracy 0.796875
# Validation accuracy 0.741477
# Time elapsed 3.3889471809069316 minutes
# Epoch 128, training loss 0.458761, accuracy 0.796875
# Validation accuracy 0.751420
# Time elapsed 3.4118680477142336 minutes
# Epoch 129, training loss 0.388700, accuracy 0.828125
# Validation accuracy 0.761364
# Time elapsed 3.4350138306617737 minutes
# Epoch 130, training loss 0.422249, accuracy 0.812500
# Validation accuracy 0.751420
# Time elapsed 3.459722137451172 minutes
# Epoch 131, training loss 0.453160, accuracy 0.781250
# Validation accuracy 0.747159
# Time elapsed 3.4849236329396565 minutes
# Epoch 132, training loss 0.481965, accuracy 0.781250
# Validation accuracy 0.759943
# Time elapsed 3.5094303210576374 minutes
# Epoch 133, training loss 0.339842, accuracy 0.906250
# Validation accuracy 0.747159
# Time elapsed 3.5317669113477073 minutes
# Epoch 134, training loss 0.433873, accuracy 0.812500
# Validation accuracy 0.748580
# Time elapsed 3.554576909542084 minutes
# Epoch 135, training loss 0.489526, accuracy 0.843750
# Validation accuracy 0.741477
# Time elapsed 3.578321433067322 minutes
# Epoch 136, training loss 0.541998, accuracy 0.718750
# Validation accuracy 0.752841
# Time elapsed 3.60319770971934 minutes
# Epoch 137, training loss 0.511911, accuracy 0.765625
# Validation accuracy 0.758523
# Time elapsed 3.6288041353225706 minutes
# Epoch 138, training loss 0.423626, accuracy 0.843750
# Validation accuracy 0.727273
# Time elapsed 3.650568381945292 minutes
# Epoch 139, training loss 0.415647, accuracy 0.859375
# Validation accuracy 0.754261
# Time elapsed 3.67322860956192 minutes
# Epoch 140, training loss 0.304278, accuracy 0.890625
# Validation accuracy 0.759943
# Time elapsed 3.6961739818255106 minutes
# Epoch 141, training loss 0.263050, accuracy 0.875000
# Validation accuracy 0.752841
# Time elapsed 3.721836785475413 minutes
# Epoch 142, training loss 0.452898, accuracy 0.750000
# Validation accuracy 0.750000
# Time elapsed 3.748394723733266 minutes
# Epoch 143, training loss 0.492741, accuracy 0.781250
# Validation accuracy 0.762784
# Time elapsed 3.7723644932111102 minutes
# Epoch 144, training loss 0.447180, accuracy 0.781250
# Validation accuracy 0.748580
# Time elapsed 3.7952611366907756 minutes
# Epoch 145, training loss 0.423747, accuracy 0.859375
# Validation accuracy 0.755682
# Time elapsed 3.8177670160929362 minutes
# Epoch 146, training loss 0.262149, accuracy 0.953125
# Validation accuracy 0.767045
# Time elapsed 3.8415597597757976 minutes
# Epoch 147, training loss 0.483797, accuracy 0.796875
# Validation accuracy 0.768466
# Time elapsed 3.8677488764127097 minutes
# Epoch 148, training loss 0.460527, accuracy 0.781250
# Validation accuracy 0.741477
# Time elapsed 3.893694504102071 minutes
# Epoch 149, training loss 0.475925, accuracy 0.828125
# Validation accuracy 0.764205
# Time elapsed 3.9162442803382875 minutes
# Epoch 150, training loss 0.385592, accuracy 0.812500
# Validation accuracy 0.752841
# Time elapsed 3.9387096802393597 minutes
# Epoch 151, training loss 0.439636, accuracy 0.781250
# Validation accuracy 0.758523
# Time elapsed 3.9619192481040955 minutes
# Epoch 152, training loss 0.408559, accuracy 0.859375
# Validation accuracy 0.767045
# Time elapsed 3.9864864309628802 minutes
# Epoch 153, training loss 0.292176, accuracy 0.906250
# Validation accuracy 0.758523
# Time elapsed 4.011826276779175 minutes
# Epoch 154, training loss 0.408710, accuracy 0.828125
# Validation accuracy 0.757102
# Time elapsed 4.036460443337758 minutes
# Epoch 155, training loss 0.416450, accuracy 0.828125
# Validation accuracy 0.731534
# Time elapsed 4.059036004543304 minutes
# Epoch 156, training loss 0.454817, accuracy 0.796875
# Validation accuracy 0.758523
# Time elapsed 4.081698071956635 minutes
# Epoch 157, training loss 0.368949, accuracy 0.859375
# Validation accuracy 0.735795
# Time elapsed 4.104723457495371 minutes
# Epoch 158, training loss 0.403794, accuracy 0.859375
# Validation accuracy 0.754261
# Time elapsed 4.130489373207093 minutes
# Epoch 159, training loss 0.396591, accuracy 0.859375
# Validation accuracy 0.759943
# Time elapsed 4.155029292901357 minutes
# Epoch 160, training loss 0.472520, accuracy 0.796875
# Validation accuracy 0.758523
# Time elapsed 4.179762597878774 minutes
# Epoch 161, training loss 0.402216, accuracy 0.828125
# Validation accuracy 0.758523
# Time elapsed 4.203078540166219 minutes
# Epoch 162, training loss 0.436204, accuracy 0.765625
# Validation accuracy 0.767045
# Time elapsed 4.2263656457265215 minutes
# Epoch 163, training loss 0.360393, accuracy 0.828125
# Validation accuracy 0.764205
# Time elapsed 4.2513702750206 minutes
# Epoch 164, training loss 0.332760, accuracy 0.859375
# Validation accuracy 0.754261
# Time elapsed 4.276854395866394 minutes
# Epoch 165, training loss 0.418172, accuracy 0.750000
# Validation accuracy 0.759943
# Time elapsed 4.301335684458414 minutes
# Epoch 166, training loss 0.446622, accuracy 0.796875
# Validation accuracy 0.776989
# Time elapsed 4.323772676785787 minutes
# Epoch 167, training loss 0.375218, accuracy 0.796875
# Validation accuracy 0.772727
# Time elapsed 4.3476078470548 minutes
# Epoch 168, training loss 0.348016, accuracy 0.843750
# Validation accuracy 0.752841
# Time elapsed 4.372215580940247 minutes
# Epoch 169, training loss 0.359561, accuracy 0.859375
# Validation accuracy 0.782670
# Time elapsed 4.397454822063446 minutes
# Epoch 170, training loss 0.377651, accuracy 0.859375
# Validation accuracy 0.774148
# Time elapsed 4.422142930825552 minutes
# Epoch 171, training loss 0.426547, accuracy 0.875000
# Validation accuracy 0.748580
# Time elapsed 4.445032016436259 minutes
# Epoch 172, training loss 0.422407, accuracy 0.765625
# Validation accuracy 0.751420
# Time elapsed 4.467939500013987 minutes
# Epoch 173, training loss 0.353055, accuracy 0.859375
# Validation accuracy 0.754261
# Time elapsed 4.492357722918192 minutes
# Epoch 174, training loss 0.254333, accuracy 0.906250
# Validation accuracy 0.765625
# Time elapsed 4.516953090826671 minutes
# Epoch 175, training loss 0.418040, accuracy 0.812500
# Validation accuracy 0.769886
# Time elapsed 4.542405192057291 minutes
# Epoch 176, training loss 0.439162, accuracy 0.796875
# Validation accuracy 0.767045
# Time elapsed 4.567086346944174 minutes
# Epoch 177, training loss 0.317554, accuracy 0.875000
# Validation accuracy 0.775568
# Time elapsed 4.589661804835002 minutes
# Epoch 178, training loss 0.332943, accuracy 0.843750
# Validation accuracy 0.762784
# Time elapsed 4.612052377065023 minutes
# Epoch 179, training loss 0.375983, accuracy 0.843750
# Validation accuracy 0.762784
# Time elapsed 4.635872280597686 minutes
# Epoch 180, training loss 0.324709, accuracy 0.875000
# Validation accuracy 0.764205
# Time elapsed 4.661805713176728 minutes
# Epoch 181, training loss 0.341250, accuracy 0.812500
# Validation accuracy 0.764205
# Time elapsed 4.688853919506073 minutes
# Epoch 182, training loss 0.392837, accuracy 0.843750
# Validation accuracy 0.768466
# Time elapsed 4.7113113085428875 minutes
# Epoch 183, training loss 0.313348, accuracy 0.906250
# Validation accuracy 0.782670
# Time elapsed 4.734615290164948 minutes
# Epoch 184, training loss 0.306410, accuracy 0.859375
# Validation accuracy 0.772727
# Time elapsed 4.756211539109548 minutes
# Epoch 185, training loss 0.358434, accuracy 0.843750
# Validation accuracy 0.781250
# Time elapsed 4.78063604036967 minutes
# Epoch 186, training loss 0.391817, accuracy 0.828125
# Validation accuracy 0.768466
# Time elapsed 4.806078906853994 minutes
# Epoch 187, training loss 0.436632, accuracy 0.750000
# Validation accuracy 0.772727
# Time elapsed 4.831116592884063 minutes
# Epoch 188, training loss 0.441713, accuracy 0.796875
# Validation accuracy 0.772727
# Time elapsed 4.853469506899516 minutes
# Epoch 189, training loss 0.294434, accuracy 0.921875
# Validation accuracy 0.759943
# Time elapsed 4.876098958651225 minutes
# Epoch 190, training loss 0.417893, accuracy 0.859375
# Validation accuracy 0.778409
# Time elapsed 4.898660365740458 minutes
# Epoch 191, training loss 0.483922, accuracy 0.781250
# Validation accuracy 0.771307
# Time elapsed 4.923902304967244 minutes
# Epoch 192, training loss 0.318052, accuracy 0.890625
# Validation accuracy 0.767045
# Time elapsed 4.949561397234599 minutes
# Epoch 193, training loss 0.299042, accuracy 0.921875
# Validation accuracy 0.778409
# Time elapsed 4.974244964122772 minutes
# Epoch 194, training loss 0.309112, accuracy 0.906250
# Validation accuracy 0.779830
# Time elapsed 4.998746132850647 minutes
# Epoch 195, training loss 0.299266, accuracy 0.843750
# Validation accuracy 0.778409
# Time elapsed 5.021070921421051 minutes
# Epoch 196, training loss 0.392453, accuracy 0.843750
# Validation accuracy 0.778409
# Time elapsed 5.04528124332428 minutes
# Epoch 197, training loss 0.444858, accuracy 0.843750
# Validation accuracy 0.772727
# Time elapsed 5.071104466915131 minutes
# Epoch 198, training loss 0.339548, accuracy 0.828125
# Validation accuracy 0.769886
# Time elapsed 5.096702186266581 minutes
# Epoch 199, training loss 0.305518, accuracy 0.906250
# Validation accuracy 0.782670
# Time elapsed 5.119046759605408 minutes
# Testing set accuracy 0.773438

# %%
# Plotting gradients
n_layers = len(tf.trainable_variables()) // 2
x = np.arange(epochs)
i = 0
plt.figure()
while i < n_layers*2:
    plt.errorbar(x,mean_gradients[i,:],std_gradients[i,:])
    i = i + 2
plt.yscale('log')
plt.ylabel('Gradient')
plt.xlabel('Epochs')
plt.title('Weights Gradient by Layer')
plt.legend(["conv1","conv2","fc1","fc2"][-n_layers:])
plt.xlim(-0.2, epochs)
plt.show()
i = 1
plt.figure()
while i < n_layers*2:
    plt.errorbar(x,mean_gradients[i,:],std_gradients[i,:])
    i = i + 2
plt.yscale('log')
plt.ylabel('Gradient')
plt.xlabel('Epochs')
plt.title('Biases Gradient by Layer')
plt.legend(["conv1","conv2","fc1","fc2"][-n_layers:])
plt.xlim(-0.2, epochs)
plt.show()

# %%
def confusion_matrix(targets, outputs):
    '''Returns a confusion matrix. Both targets and outputs
    should be 1-D arrays of zeros and ones.'''
    encoded_data = 2*targets+outputs  # Map targets and outputs to {0, 1, 2, 3}
    TN = np.sum(encoded_data == 0)  # True negatives
    FP = np.sum(encoded_data == 1)  # False positives
    FN = np.sum(encoded_data == 2)  # False negatives
    TP = np.sum(encoded_data == 3)  # True positives
    return ((TP, FP), (FN, TN))

def roc_curve(targets, outputs):
    '''Returns a ROC curve. Outputs should be in range 0-1
    in order to move the threshold.'''
    tpr = []
    fpr = []
    for threshold in np.linspace(0, 1, 1000):
        outputs_with_threshold = (outputs > threshold).astype(np.float)
        ((TP, FP), (FN, TN)) = confusion_matrix(
            targets, 
            outputs_with_threshold)
        tpr.append(TP/(TP+FN))
        fpr.append(FP/(FP+TN))
    return np.array(tpr), np.array(fpr)

accs = sess.run(accuracy,
             feed_dict={
            model_input: cifar10.training_data,
                       target: cifar10.training_labels,
            keep_prob: 1.0
        })

accs = np.asarray(accs)
[[VN,FP],[FN,VP]] = confusion_matrix(
    accs,
    (accs>0.5).astype(np.float))
print('VP: %d, VN: %d, FP: %d, FN: %d' %(VP,VN,FP,FN))
print('Porcentaje de clasificaciones correctas: %%%f' %(100.0*(VP+VN)/(VP+VN+FP+FN)))
print('Precision: %%%f' %(100.0*VP/(VP+FP)))
print('Recall: %%%f' %(100.0*VP/(VP+FN)))
print('')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-58da638e24cd> in <module>()
#      25 accs = sess.run(accuracy,
#      26              feed_dict={
# ---> 27             model_input: cifar10.training_data,
#      28                        target: cifar10.training_labels,
#      29             keep_prob: 1.0
#
# AttributeError: 'CIFAR10' object has no attribute 'training_data'
